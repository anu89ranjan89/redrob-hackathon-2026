# %%
import pandas as pd

# %%
df = pd.read_csv("../data/ranked_candidates.csv")

# %% [markdown]
# df.head(20)

# %%
print("Average Score")
print(df["score"].mean())

# %%
print("Top Candidate")
print(df.iloc[0])
